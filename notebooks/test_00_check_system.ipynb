# %% [markdown]
# 00_check_system

# %%
from variables import work_dir
from SOURCE.tools import checks

print()

# %%
# check if the module checks is installed
print("dir(checks) :",dir(checks))
print()
# Out:
# dir(checks) : ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'check_directory', 'check_modules_installed', 'check_py_version', 'modules_install']

# %%
# check the python version
checks.check_py_version()
print()
# Out:
# Python version:  3.10.12

# %%
# check the modules installed
checks.check_modules_installed()
print()
# Out:
# The check is based on the 'requirements.txt' for the creation of an docker image !!
# you need to install:  dumper  --  pip install dumper
# you need to install:  pyMuPDF  --  pip install pyMuPDF

# %%
print("if you like to install automatically all the module, edit the file src/00_check_system and uncomment the line with the command 'checks.modules_install()'")

# install all the modules required
#checks.modules_install()
print()
# Out:
# if you like to install automatically all the module, edit the file src/00_check_system and uncomment the line with the command 'checks.modules_install()'
