# %% [markdown]
# 01_download

# %%
from variables import work_dir
from SOURCE import *
# import specific modules for copernicus
from SOURCE.data_source.copernicus import *

# %%
import copernicusmarine as cm

import datasets as dts
from variables import input_dir
from variables import output_dir
from variables import downld_directory as download_dir
from variables import downld_flag_bbox as flag_bbox
from variables import downld_targeted_bbox as targeted_bbox
from variables import downld_check_map as map
# uncomment the variable for bbox or poly
# bbox
#from variables import downls_bbox_geom as aoi_geom
# poly
from variables import downld_poly_geom as aoi_geom
from variables import downld_poly_edge as edge
#
from variables import map_flavours
from variables import max_num_downld_files as numberOfFiles
from variables import targeted_range

# %%
print("input !!")

print(input_dir)
print(output_dir)
print(cm.__version__)
print()

tools.checks.check_directory(input_dir)
tools.checks.check_directory(output_dir)
tools.checks.check_directory(download_dir)
# Out:
# input !!
# /home/geofrizz/INGV/source/Source/input/
# /home/geofrizz/INGV/source/Source/output/
# 1.3.2

# %% [markdown]
# Login to Copernicus Marine

# %%
# login to copernicus marine just one time
#cm.login()

# %%
# loop over datasets
for dataset, data in dts.datasets.items():
  print("dataset :",dataset)

  # downlod index files from copernicusmarine
  data_source.copernicus.utilities.download_index(input_dir,dataset,data)

  print("Ready !")
# Out:
# dataset : cmems_obs-ins_glo_phybgcwav_mynrt_na_irr
# Fetching catalog: 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:10<00:00,  3.38s/it]
# INFO - 2024-08-14T09:31:12Z - You forced selection of dataset version "202311"
# INFO - 2024-08-14T09:31:12Z - Dataset part was not specified, the first one was selected: "latest"
# INFO - 2024-08-14T09:31:12Z - You forced selection of service: original-files
# INFO - 2024-08-14T09:31:12Z - Downloading using service original-files...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:26<00:00,  6.70s/it]
# Ready !

# %%
  
  map_aoi = tools.utilities.jupiter_create_map_aoi(aoi_geom,flag_bbox,map,map_flavours[0])
  map_aoi
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d078a53c06f8db1a0e024aad83208ac3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d078a53c06f8db1a0e024aad83208ac3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d078a53c06f8db1a0e024aad83208ac3 = L.map(
#                 &quot;map_d078a53c06f8db1a0e024aad83208ac3&quot;,
#                 {
#                     center: [38.0, 20.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad996c752858f9b8c76cf1434eb581e2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ad996c752858f9b8c76cf1434eb581e2.addTo(map_d078a53c06f8db1a0e024aad83208ac3);
#
#
#
#         function geo_json_0a026297aa974c039fe35607ecddc248_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0a026297aa974c039fe35607ecddc248 = L.geoJson(null, {
#                 onEachFeature: geo_json_0a026297aa974c039fe35607ecddc248_onEachFeature,
#
#                 color: &quot;red&quot;,
#         });
#
#         function geo_json_0a026297aa974c039fe35607ecddc248_add (data) {
#             geo_json_0a026297aa974c039fe35607ecddc248
#                 .addData(data);
#         }
#             geo_json_0a026297aa974c039fe35607ecddc248_add({&quot;coordinates&quot;: [[[-18.5, 30.0], [-18.5, 43.2], [-0.8, 43.2], [16.0, 46.5], [26.8, 41.8], [26.8, 40.3], [36.5, 38.0], [36.5, 30.0], [-18.5, 30.0]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_0a026297aa974c039fe35607ecddc248.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_0a026297aa974c039fe35607ecddc248.addTo(map_d078a53c06f8db1a0e024aad83208ac3);
#
#
#                 var lat_lng_popup_e2331ed64e14ea2b486443adb6782078 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_e2331ed64e14ea2b486443adb6782078
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_d078a53c06f8db1a0e024aad83208ac3);
#                     }
#                 map_d078a53c06f8db1a0e024aad83208ac3.on(&#x27;click&#x27;, latLngPop);
#
#
#             map_d078a53c06f8db1a0e024aad83208ac3.fitBounds(
#                 [[30.0, -18.5], [46.5, 36.5]],
#                 {}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
  info = data_source.copernicus.copernicus_functions.getIndexFilesInfo(
    data["details"],
    input_dir,
    targeted_bbox, 
    aoi_geom
  )

  print("targeted range:",targeted_range)
  info['timeOverlap'] = info.apply(
    data_source.copernicus.copernicus_functions.timeOverlap,
    targeted_range=targeted_range,
    axis=1
  )

  # apply the filter
  subset = data_source.copernicus.utilities.filter_downloads(info,data["filters"])
  #print(subset.head())
  #print()

  # create download list
  data_source.copernicus.utilities.download_files_list(subset)

  # download data from copernicusmarine
  data_source.copernicus.utilities.download_data(dataset,download_dir)

  print("Done !!")
# Out:
# ...Loading info from: index_platform.txt
# ...Loading info from: index_history.txt
# Ready!
# targeted range: 2024-05-27T00:00:00Z/2024-06-10T00:00:00Z
# INFO - 2024-08-14T09:32:11Z - Dataset version was not specified, the latest one was selected: "202311"
# INFO - 2024-08-14T09:32:11Z - You forced selection of dataset part "history"
# INFO - 2024-08-14T09:32:11Z - Service was not specified, the default one was selected: "original-files"
# INFO - 2024-08-14T09:32:11Z - Downloading using service original-files...
# Done !!

# %%
  # Check the position of the data:
  map_check = tools.utilities.jupiter_create_map_checkdata(aoi_geom,edge,flag_bbox,map,numberOfFiles,subset,map_flavours[17])
  map_check
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb99355afe9001ccb0fca56dcc9a65f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb99355afe9001ccb0fca56dcc9a65f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb99355afe9001ccb0fca56dcc9a65f5 = L.map(
#                 &quot;map_bb99355afe9001ccb0fca56dcc9a65f5&quot;,
#                 {
#                     center: [38.0, 20.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4109f042d53dbdfed954784c4272af41 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/rastertiles/voyager_nolabels/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4109f042d53dbdfed954784c4272af41.addTo(map_bb99355afe9001ccb0fca56dcc9a65f5);
#
#
#
#         function geo_json_bd894933bf773aecf72a36161334af92_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_bd894933bf773aecf72a36161334af92 = L.geoJson(null, {
#                 onEachFeature: geo_json_bd894933bf773aecf72a36161334af92_onEachFeature,
#
#                 color: &quot;red&quot;,
#         });
#
#         function geo_json_bd894933bf773aecf72a36161334af92_add (data) {
#             geo_json_bd894933bf773aecf72a36161334af92
#                 .addData(data);
#         }
#             geo_json_bd894933bf773aecf72a36161334af92_add({&quot;coordinates&quot;: [[[-18.5, 30.0], [-18.5, 43.2], [-0.8, 43.2], [16.0, 46.5], [26.8, 41.8], [26.8, 40.3], [36.5, 38.0], [36.5, 30.0], [-18.5, 30.0]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_bd894933bf773aecf72a36161334af92.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_bd894933bf773aecf72a36161334af92.addTo(map_bb99355afe9001ccb0fca56dcc9a65f5);
#
#
#                 var lat_lng_popup_ee6fa65b2965c33bbc67321503d9f766 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_ee6fa65b2965c33bbc67321503d9f766
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_bb99355afe9001ccb0fca56dcc9a65f5);
#                     }
#                 map_bb99355afe9001ccb0fca56dcc9a65f5.on(&#x27;click&#x27;, latLngPop);
#
#
#             var marker_e8835aa4ec871c24947beacf236e9a79 = L.marker(
#                 [43.38, 7.83],
#                 {}
#             ).addTo(map_bb99355afe9001ccb0fca56dcc9a65f5);
#
#
#             var icon_03b8761fd5cc54bea8d03c3773f8d077 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e8835aa4ec871c24947beacf236e9a79.setIcon(icon_03b8761fd5cc54bea8d03c3773f8d077);
#
#
#         var popup_079987ffccdda94181aaa13d45d4bbce = L.popup({&quot;maxWidth&quot;: 400, &quot;minWidth&quot;: 150});
#
#
#
#                 var html_047768b793b4155b4707dada8554913c = $(`&lt;div id=&quot;html_047768b793b4155b4707dada8554913c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Platform code: &lt;/b&gt;&lt;nowrap&gt;6100001&lt;br&gt;&lt;b&gt;Institution: &lt;/b&gt;&lt;nowrap&gt;Meteo France Centre de Météorologie Marine&lt;br&gt;&lt;b&gt;Last Lat.: &lt;/b&gt;&lt;nowrap&gt;43.38&lt;br&gt;&lt;b&gt;Last Lon.: &lt;/b&gt;&lt;nowrap&gt;7.83&lt;br&gt;&lt;b&gt;Last Observation.: &lt;/b&gt;&lt;nowrap&gt;2024 Aug 13 - 23:00:00&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_079987ffccdda94181aaa13d45d4bbce.setContent(html_047768b793b4155b4707dada8554913c);
#
#
#
#         marker_e8835aa4ec871c24947beacf236e9a79.bindPopup(popup_079987ffccdda94181aaa13d45d4bbce)
#         ;
#
#
#
#
#             var marker_0c1d546220b86a3f8e53bbd8ed99292d = L.marker(
#                 [42.07, 4.67],
#                 {}
#             ).addTo(map_bb99355afe9001ccb0fca56dcc9a65f5);
#
#
#             var icon_c8a3c5e41de7855f83543dbc2c0f695e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0c1d546220b86a3f8e53bbd8ed99292d.setIcon(icon_c8a3c5e41de7855f83543dbc2c0f695e);
#
#
#         var popup_aa5632f2420d706bfca3a966e466374b = L.popup({&quot;maxWidth&quot;: 400, &quot;minWidth&quot;: 150});

# %%
print("Finish !")
