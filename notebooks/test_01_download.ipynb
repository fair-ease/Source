# %% [markdown]
# 01_download

# %%
from variables import work_dir
from SOURCE import *
# import specific modules for copernicus
from SOURCE.data_source.copernicus import *

# %%
import copernicusmarine as cm

import datasets as dts
from variables import input_dir
from variables import output_dir
from variables import downld_directory as download_dir
from variables import downld_flag_bbox as flag_bbox
from variables import downld_targeted_bbox as targeted_bbox
# uncomment the variable for bbox or poly
# bbox
#from variables import downls_bbox_geom as aoi_geom
# poly
from variables import downld_poly_geom as aoi_geom
from variables import downld_check_map as map
from variables import downld_poly_edge as edge
from variables import max_num_downld_files as numberOfFiles
from variables import targeted_range

# %%
print("input !!")

print(input_dir)
print(output_dir)
print(cm.__version__)
print()

tools.checks.check_directory(input_dir)
tools.checks.check_directory(output_dir)
tools.checks.check_directory(download_dir)
# Out:
# input !!
# /home/geofrizz/INGV/source/Source/input/
# /home/geofrizz/INGV/source/Source/output/
# 1.3.1

# %% [markdown]
# Login to Copernicus Marine

# %%
# login to copernicus marine just one time
#cm.login()

# %%
# loop over datasets
for dataset, data in dts.datasets.items():
  print("dataset :",dataset)

  # downlod index files from copernicusmarine
  data_source.copernicus.utilities.download_index(input_dir,dataset,data)

  print("Ready !")
# Out:
# dataset : cmems_obs-ins_glo_phybgcwav_mynrt_na_irr
# Fetching catalog: 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:57<00:00, 19.29s/it]
# INFO - 2024-08-07T13:05:29Z - You forced selection of dataset version "202311"
# INFO - 2024-08-07T13:05:29Z - Dataset part was not specified, the first one was selected: "latest"
# INFO - 2024-08-07T13:05:29Z - You forced selection of service: original-files
# INFO - 2024-08-07T13:05:29Z - Downloading using service original-files...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:27<00:00,  7.00s/it]
# Ready !

# %%
  
  map_aoi = tools.utilities.jupiter_create_map_aoi(aoi_geom,flag_bbox,map)
  map_aoi
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d0c5b7bd61209b18bf2d5f0b65c82fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d0c5b7bd61209b18bf2d5f0b65c82fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d0c5b7bd61209b18bf2d5f0b65c82fd = L.map(
#                 &quot;map_4d0c5b7bd61209b18bf2d5f0b65c82fd&quot;,
#                 {
#                     center: [38.0, 20.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e434ba74f25d4cafcb850f89117ca73 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0e434ba74f25d4cafcb850f89117ca73.addTo(map_4d0c5b7bd61209b18bf2d5f0b65c82fd);
#
#
#
#         function geo_json_addf122f4e1021d6964aadbe3db819d8_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_addf122f4e1021d6964aadbe3db819d8 = L.geoJson(null, {
#                 onEachFeature: geo_json_addf122f4e1021d6964aadbe3db819d8_onEachFeature,
#
#                 color: &quot;red&quot;,
#         });
#
#         function geo_json_addf122f4e1021d6964aadbe3db819d8_add (data) {
#             geo_json_addf122f4e1021d6964aadbe3db819d8
#                 .addData(data);
#         }
#             geo_json_addf122f4e1021d6964aadbe3db819d8_add({&quot;coordinates&quot;: [[[-18.5, 30.0], [-18.5, 43.2], [-0.8, 43.2], [16.0, 46.5], [26.8, 41.8], [26.8, 40.3], [36.5, 38.0], [36.5, 30.0], [-18.5, 30.0]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_addf122f4e1021d6964aadbe3db819d8.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_addf122f4e1021d6964aadbe3db819d8.addTo(map_4d0c5b7bd61209b18bf2d5f0b65c82fd);
#
#
#                 var lat_lng_popup_611fba931a938838632d6e35ed93312f = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_611fba931a938838632d6e35ed93312f
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_4d0c5b7bd61209b18bf2d5f0b65c82fd);
#                     }
#                 map_4d0c5b7bd61209b18bf2d5f0b65c82fd.on(&#x27;click&#x27;, latLngPop);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
  info = data_source.copernicus.copernicus_functions.getIndexFilesInfo(
    data["details"],
    input_dir,
    targeted_bbox, 
    aoi_geom
  )

  print("targeted range:",targeted_range)
  info['timeOverlap'] = info.apply(
    data_source.copernicus.copernicus_functions.timeOverlap,
    targeted_range=targeted_range,
    axis=1
  )

  # apply the filter
  subset = data_source.copernicus.utilities.filter_downloads(info,data["filters"])
  #print(subset.head())
  #print()

  # create download list
  data_source.copernicus.utilities.download_files_list(subset)

  # download data from copernicusmarine
  data_source.copernicus.utilities.download_data(dataset,download_dir)

  print("Done !!")
# Out:
# ...Loading info from: index_platform.txt
# ...Loading info from: index_history.txt
# Ready!
# targeted range: 2024-05-27T00:00:00Z/2024-06-10T00:00:00Z
# INFO - 2024-08-07T13:06:57Z - Dataset version was not specified, the latest one was selected: "202311"
# INFO - 2024-08-07T13:06:57Z - You forced selection of dataset part "history"
# INFO - 2024-08-07T13:06:57Z - Service was not specified, the default one was selected: "original-files"
# INFO - 2024-08-07T13:06:57Z - Downloading using service original-files...
# Done !!

# %%
  # Check the position of the data:
  map_check = tools.utilities.jupiter_create_map_checkdata(aoi_geom,edge,flag_bbox,map,numberOfFiles,subset)
  map_check
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8cae4e531bdf53f236e7769be5579ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8cae4e531bdf53f236e7769be5579ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8cae4e531bdf53f236e7769be5579ee = L.map(
#                 &quot;map_d8cae4e531bdf53f236e7769be5579ee&quot;,
#                 {
#                     center: [38.0, 20.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b182629e3739f5ef10aa8163ea90171d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b182629e3739f5ef10aa8163ea90171d.addTo(map_d8cae4e531bdf53f236e7769be5579ee);
#
#
#
#         function geo_json_caa59f60cdde8e8c96d44c797c91be59_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_caa59f60cdde8e8c96d44c797c91be59 = L.geoJson(null, {
#                 onEachFeature: geo_json_caa59f60cdde8e8c96d44c797c91be59_onEachFeature,
#
#                 color: &quot;red&quot;,
#         });
#
#         function geo_json_caa59f60cdde8e8c96d44c797c91be59_add (data) {
#             geo_json_caa59f60cdde8e8c96d44c797c91be59
#                 .addData(data);
#         }
#             geo_json_caa59f60cdde8e8c96d44c797c91be59_add({&quot;coordinates&quot;: [[[-18.5, 30.0], [-18.5, 43.2], [-0.8, 43.2], [16.0, 46.5], [26.8, 41.8], [26.8, 40.3], [36.5, 38.0], [36.5, 30.0], [-18.5, 30.0]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_caa59f60cdde8e8c96d44c797c91be59.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_caa59f60cdde8e8c96d44c797c91be59.addTo(map_d8cae4e531bdf53f236e7769be5579ee);
#
#
#                 var lat_lng_popup_7cccbde98c521a39f37986ef9d2c025d = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_7cccbde98c521a39f37986ef9d2c025d
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_d8cae4e531bdf53f236e7769be5579ee);
#                     }
#                 map_d8cae4e531bdf53f236e7769be5579ee.on(&#x27;click&#x27;, latLngPop);
#
#
#             var marker_277f51053d2f3d7e2edc569e8bee602c = L.marker(
#                 [43.38, 7.83],
#                 {}
#             ).addTo(map_d8cae4e531bdf53f236e7769be5579ee);
#
#
#             var icon_a7a3d81ac8f8e96f81d395c568c0fa4b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_277f51053d2f3d7e2edc569e8bee602c.setIcon(icon_a7a3d81ac8f8e96f81d395c568c0fa4b);
#
#
#         var popup_9474e639b4d79b5bbf84b53a452d305a = L.popup({&quot;maxWidth&quot;: 400, &quot;minWidth&quot;: 150});
#
#
#
#                 var html_bf2c96d2a08a4726416a00168e5dc0ef = $(`&lt;div id=&quot;html_bf2c96d2a08a4726416a00168e5dc0ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Platform code: &lt;/b&gt;&lt;nowrap&gt;6100001&lt;br&gt;&lt;b&gt;Institution: &lt;/b&gt;&lt;nowrap&gt;Meteo France Centre de Météorologie Marine&lt;br&gt;&lt;b&gt;Last Lat.: &lt;/b&gt;&lt;nowrap&gt;43.38&lt;br&gt;&lt;b&gt;Last Lon.: &lt;/b&gt;&lt;nowrap&gt;7.83&lt;br&gt;&lt;b&gt;Last Observation.: &lt;/b&gt;&lt;nowrap&gt;2024 Aug 07 - 03:00:00&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_9474e639b4d79b5bbf84b53a452d305a.setContent(html_bf2c96d2a08a4726416a00168e5dc0ef);
#
#
#
#         marker_277f51053d2f3d7e2edc569e8bee602c.bindPopup(popup_9474e639b4d79b5bbf84b53a452d305a)
#         ;
#
#
#
#
#             var marker_5829735b624ab0e0a84d5201a0ea4b62 = L.marker(
#                 [42.0643, 4.6651],
#                 {}
#             ).addTo(map_d8cae4e531bdf53f236e7769be5579ee);
#
#
#             var icon_a5c4bfe4983bf0511cfc14ff4e77be5a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5829735b624ab0e0a84d5201a0ea4b62.setIcon(icon_a5c4bfe4983bf0511cfc14ff4e77be5a);
#
#
#         var popup_1051985d30e2358e323aefc9812bd9ec = L.popup({&quot;maxWidth&quot;: 400, &quot;minWidth&quot;: 150});
#
#
#
#                 var html_d178b6f29089b5397c52ffeddcc34bd6 = $(`&lt;div id=&quot;html_d178b6f29089b5397c52ffeddcc34bd6&quot; styl

# %%
print("Finish !")
# Out:
# Finish !
